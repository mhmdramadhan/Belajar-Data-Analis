# %% [markdown]
# # Fungsi/Method Statistik
#
# Pandas menyediakan berbagai fungsi statistik yang berguna untuk menganalisis data.

# %%
import pandas as pd
pd.options.display.precision = 4

path = '/content/drive/MyDrive/Belajar Data Analisis Python/sample_data/Pokemon.csv'
df = pd.read_csv(path, index_col='Num')
df
# Out:
#            Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Num
# 1     Bulbasaur    Grass  Poison    318   45      49       49       65
# 2       Ivysaur    Grass  Poison    405   60      62       63       80
# 3      Venusaur    Grass  Poison    525   80      82       83      100
# 4    Charmander     Fire     NaN    309   39      52       43       60
# 5    Charmeleon     Fire     NaN    405   58      64       58       80
# ..          ...      ...     ...    ...  ...     ...      ...      ...
# 147     Dratini   Dragon     NaN    300   41      64       45       50
# 148   Dragonair   Dragon     NaN    420   61      84       65       70
# 149   Dragonite   Dragon  Flying    600   91     134       95      100
# 150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# Num
# 1         65     45      1      False
# ...

# %%
df.sample(5)
# Out:
#           Name    Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Num
# 35    Clefairy     Fairy     NaN    323  70      45       48       60
# 34    Nidoking    Poison  Ground    505  81     102       77       85
# 148  Dragonair    Dragon     NaN    420  61      84       65       70
# 54     Psyduck     Water     NaN    320  50      52       48       65
# 101  Electrode  Electric     NaN    480  60      50       70       80
#
#      Sp. Def  Speed  Stage  Legendary
# Num
# 35        65     35      1      False
# 34        75     85      3      False
# 148       70     70      2      False
# 54        50     55      1      False
# 101       80    140      2      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, 1 to 151
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       151 non-null    object
#  1   Type 1     151 non-null    object
#  2   Type 2     67 non-null     object
#  3   Total      151 non-null    int64
#  4   HP         151 non-null    int64
#  5   Attack     151 non-null    int64
#  6   Defense    151 non-null    int64
#  7   Sp. Atk    151 non-null    int64
#  8   Sp. Def    151 non-null    int64
#  9   Speed      151 non-null    int64
#  10  Stage      151 non-null    int64
#  11  Legendary  151 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 14.3+ KB

# %% [markdown]
# ### describe
#
# Fungsi ini memberikan ringkasan statistik dari DataFrame atau Series, termasuk jumlah, rata-rata, standar deviasi, nilai minimum dan maksimum, serta persentil

# %%
df.describe(exclude=['object'])
# Out:
#            Total        HP    Attack   Defense   Sp. Atk   Sp. Def     Speed  \
# count   151.0000  151.0000  151.0000  151.0000  151.0000  151.0000  151.0000
# unique       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# top          NaN       NaN       NaN       NaN       NaN       NaN       NaN
# freq         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# mean    407.0795   64.2119   72.5497   68.2252   67.1391   66.0199   68.9338
# std      99.7438   28.5901   26.5962   26.9167   28.5342   24.1979   26.7469
# min     195.0000   10.0000    5.0000    5.0000   15.0000   20.0000   15.0000
# 25%     320.0000   45.0000   51.0000   50.0000   45.0000   49.0000   46.5000
# 50%     405.0000   60.0000   70.0000   65.0000   65.0000   65.0000   70.0000
# 75%     490.0000   80.0000   90.0000   84.0000   87.5000   80.0000   90.0000
# max     680.0000  250.0000  134.0000  180.0000  154.0000  125.0000  140.0000
#
#            Stage Legendary
# ...

# %%
df.describe(include=['object'])
# Out:
#               Name Type 1  Type 2
# count          151    151      67
# unique         150     15      11
# top     Nidoran���  Water  Poison
# freq             2     28      19

# %% [markdown]
# ### Fungsi statistik secara spesifik

# %% [markdown]
# #### Semua kolom/baris

# %%
df.mean(numeric_only=True, axis=0) # axis bisa diganti 0 (kolom) atau 1 (baris)
# Out:
# Total        407.0795
# HP            64.2119
# Attack        72.5497
# Defense       68.2252
# Sp. Atk       67.1391
# Sp. Def       66.0199
# Speed         68.9338
# Stage          1.5828
# Legendary      0.0265
# dtype: float64

# %%
df.median(numeric_only=True, axis=0) # axis bisa diganti 0 (kolom) atau 1 (baris)
# Out:
# Total        405.0
# HP            60.0
# Attack        70.0
# Defense       65.0
# Sp. Atk       65.0
# Sp. Def       65.0
# Speed         70.0
# Stage          1.0
# Legendary      0.0
# dtype: float64

# %%
max_df = df.max(numeric_only=True, axis=0) # axis bisa diganti 0 (kolom) atau 1 (baris)

# %%
type(max_df)
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### Kolom/Baris Tertentu

# %%
df.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Stage', 'Legendary'],
#       dtype='object')

# %%
df['Attack'].mean()
# Out:
# 72.54966887417218

# %%
type(df['Attack'].mean())
# Out:
# numpy.float64

# %%
target = ['Attack', 'Sp. Atk']
df[target].mean()
# Out:
# Attack     72.5497
# Sp. Atk    67.1391
# dtype: float64

# %%
df['Sp. Atk'].skew()
# Out:
# 0.499756406343774

# %% [markdown]
# Fungsi statistik deskriptif lainnya:
#
# 1. mean(): Menghitung rata-rata.
# 2. median(): Menghitung nilai tengah (median).
# 3. mode(): Mengembalikan nilai yang paling sering muncul.
# 4. std(): Menghitung standar deviasi.
# 5. var(): Menghitung variansi.
# 6. mad(): Menghitung deviasi absolut rata-rata.
# 7. min(): Mengembalikan nilai minimum.
# 8. max(): Mengembalikan nilai maksimum.
# 9. sum(): Menghitung jumlah total.
# 10. count(): Menghitung jumlah nilai non-null.
# 11. quantile(): Mengembalikan nilai persentil.
# 12. cumsum(): Menghitung jumlah kumulatif.
# 13. cumprod(): Menghitung hasil kali kumulatif.
# 14. cummin(): Menghitung nilai minimum kumulatif.
# 15. cummax(): Menghitung nilai maksimum kumulatif.
# 16. corr(): Menghitung matriks korelasi.
# 17. skew(): Menghitung skewness (kemiringan distribusi).
# 18. kurt(): Menghitung kurtosis (keruncingan distribusi).
